# %%
import sys
sys.path.insert(0, r"C:\Users\paco_\OneDrive\Escritorio\repos\drone_reserve\src")

from drone_reserve.utils import load_rasters, build_point_cloud, build_mesh, launch_viewer, activate_gpu

# activate_gpu(device_id=0)

xyz, colors, meta = load_rasters(r"C:\Users\paco_\OneDrive\Escritorio\repos\drone_reserve\data\talar.tif",
                                 r"C:\Users\paco_\OneDrive\Escritorio\repos\drone_reserve\data\talar.tif",
                                 downsample=2)

# pcd = build_point_cloud(xyz, colors, z_scale=1.0, voxel_size=0.5)
mesh = build_mesh(xyz, colors, z_scale=1.0)
launch_viewer(mesh)        # ← opens a native window; cell blocks until you close it
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 8
#       4 from drone_reserve.utils import load_rasters, build_point_cloud, build_mesh, launch_viewer, activate_gpu
#       5
#       6 # activate_gpu(device_id=0)
#       7
# ----> 8 xyz, colors, meta = load_rasters(r"C:\Users\paco_\OneDrive\Escritorio\repos\drone_reserve\data\talar.tif",
#       9                                  r"C:\Users\paco_\OneDrive\Escritorio\repos\drone_reserve\data\talar.tif",
#      10                                  downsample=2)
#      11
#
# File ~\OneDrive\Escritorio\repos\drone_reserve\src\drone_reserve\utils.py:175, in load_rasters(ortho_path, dem_path, downsample)
#     142 def load_rasters(
#     143     ortho_path: str | Path,
#     144     dem_path: str | Path,
#     145     downsample: int = 5,
#     146 ) -> tuple[np.ndarray, np.ndarray, dict]:
#     147     """Load and align an orthomosaic (RGB/RGBA) and a DEM raster.
#     148
#     149     Heavy array math runs on GPU when :func:`activate_gpu` has been called.
#    (...)    173         If either path doesn't exist (per project rule: no silent fallbacks).
#     174     """
# --> 175     ortho_path = resolve_path(ortho_path)
#     176     dem_path = resolve_path(dem_path)
#     178     xp = GPU.xp  # numpy or cupy
#
# File ~\OneDrive\Escritorio\repos\drone_reserve\src\drone_reserve\io.py:21, in resolve_path(p)
#      19 path = Path(p).expanduser().resolve()
#      20 if not path.exists():
# ---> 21     raise FileNotFoundError(f"Expected input not found: {path}")
#      22 return path
#
# FileNotFoundError: Expected input not found: C:\Users\paco_\OneDrive\Escritorio\repos\drone_reserve\data\talar.tif
